# %%
import memex as x
x.random_scan()

# %% [markdown]
# The CDF of a Weibull distribution is $1-e^{-(x/\lambda)^k}$ if $k$ > 1
# or 0 otherwise.

# %%
import matplotlib.pyplot as plt
plt.style.use(['ieee','science'])
import numpy as np
def weibull(x,scale=1,shape=1) :
    x = np.array(x)
    y = 1-np.exp(-np.power(x/scale,shape))
    return y
x = np.linspace(0,1,1000)
y = weibull(x,0.1,0.5)
plt.plot(x,y)

# %%
# %matplotlib notebook
import ipywidgets as w
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi,1000)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()

w.interact(update);
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…

# %%
def get_group(group,bias=['0.6V','0.9V','1.2V','1.5V']) :
    data = pd.read_csv('data/sram/seu_sept2021/xs.csv')
    data = data.set_index(['Group','Bias','LET'])
    df = pd.DataFrame()
    for b in bias :
        x = data.xs((group,b)).index
        y = data.xs((group,b))['XS']
        err = data.xs((group,b))['Error']
        if df.empty :
            df = pd.DataFrame(y.rename(b))
        else :
            df = df.join(y.rename(b))
    return df

import matplotlib.pyplot as plt
plt.style.use(['ieee','science'])
import numpy as np
def weibull(x,scale=1,shape=1) :
    x = np.array(x)
    y = 1-np.exp(-np.power(x/scale,shape))
    return y

import pandas as pd
y = get_group('F')
y = y.stack().xs('0.6V',level=1)
x = y.index

# %matplotlib notebook
import ipywidgets as w
x_fit = np.linspace(x[0],x[-1],100)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
y_fit = weibull(x,1,1)
line, = ax.plot(x,y,'.')#x_fit, y_fit,'-',

def update(scale=1.0,shape=1.0):
    y_fit = weibull(x,scale,shape)
    line.set_ydata(y)#y_fit,
    fig.canvas.draw_idle()

w.interact(update);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/async_helpers.py:68: PerformanceWarning: indexing past lexsort depth may impact performance.
#   coro.send(None)
# <img src="data:image/png;base64,..." width="2100">
# interactive(children=(FloatSlider(value=1.0, description='scale', max=3.0, min=-1.0), FloatSlider(value=1.0, d…
